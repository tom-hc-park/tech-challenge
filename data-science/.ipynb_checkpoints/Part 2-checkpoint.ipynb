# %% [markdown]
# # Part 2: System Analysis & Optimization
# There are multiple directions of interest, and the ideas were listed in ascending order of complexity.
#
# ## Idea 1: Text Note Classification
# Keep the quality of human written text data with consistency
#
# ## Idea 2: Detect Redundant Censor for Minizing Cost
# SHARP values
# Clustering covariates
# Multicolinearity (correlations between covariates)
#
# ## Idea 2: Early Warning System
# Probability of red flag: bivariate result utilization with logistic regression
# Algorithm (rules/models) for not too late intervention
#
# ## Idea 3: Operating Regime Profiling (template)
# - Cluster sensor patterns when the system is normal
# - Compare clusters between alert vs. normal conditions
# - Propose operating guidelines or thresholds to avoid alerts

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import os

# %%
df = pd.read_csv('./dataset/train.csv')

# %% [markdown]
# ## Text Note Classification
# Assumption: Operational_Notes field is written by technician manually.
# Situation: a note is written in a new way that it does not exactly match with any of the cleaned existing Operational_Note value.
# Goal: to find the closest note for the new variation of human writing.

# %%
known_notes = df['Operational_Notes'].dropna().unique().tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Fit TF-IDF on known notes
vectorizer = TfidfVectorizer()
X_known = vectorizer.fit_transform(known_notes)

def classify_note(new_note):
    # Transform the new note
    X_new = vectorizer.transform([new_note])
    
    # Compute cosine similarity
    similarities = cosine_similarity(X_new, X_known).flatten()
    
    # Find the best match
    best_idx = np.argmax(similarities)
    return known_notes[best_idx], similarities[best_idx]

# %%
known_notes
# Out:
# ['Parameters logged',
#  'Nominal operation',
#  'Pressures stable',
#  'Routine check by operator',
#  'Stroke rate steady',
#  'Weather condition normal',
#  'Initial strokes',
#  'Bringing online after workover',
#  'Flowline pressured up',
#  'Well restart initiated',
#  'Confirming stroke length',
#  'Flow consistent',
#  'High motor amps',
#  'Stuffing box leak',
#  'Possible rod parting',
#  'Flow rate drop',
#  'Gas interference suspected',
#  'Fluid pound detected',
#  'Polished rod load erratic',
#  'Temp anomaly gearbox',
#  'High vibration gearbox',
#  'Pressure spike tubing',
#  'Stuffing box replaced',
#  'Valve repair',
#  'Polished rod clamp adjusted',
#  'Fluid level check',
#  'Pump serviced',
#  'Rod string pulled',
#  'Workover rig on site',
#  'Gearbox oil change',
#  'Paraffin cleaned',
#  'Routine check',
#  'VFD ramp up',
#  'Well shut-in - waiting orders',
#  'Waiting on flowline',
#  'Well shut-in - low price',
#  'Monitoring pressures',
#  'Well shut-in - surface repair',
#  'Checking surface equipment']

# %%
# Example 1
note = "well was shut down for repairs"
closest_note, score = classify_note(note)
print(f"Closest note: {closest_note} (Similarity: {score:.2f})")
# Out:
# Closest note: Well shut-in - surface repair (Similarity: 0.60)

# %%
# Example 2 
note = "Pump repair done"
closest_note, score = classify_note(note)
print(f"Closest note: {closest_note} (Similarity: {score:.2f})")
# Out:
# Closest note: Pump serviced (Similarity: 0.53)

# %%
# Example 3 
# Example 2 
note = "Well starting"
closest_note, score = classify_note(note)
print(f"Closest note: {closest_note} (Similarity: {score:.2f})")
# Out:
# Closest note: Well restart initiated (Similarity: 0.48)

# %% [markdown]
# ## Detect Redundant Censor for Minizing Cost

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Subset your numeric sensor columns 
sensor_cols = [col for col in df.columns if col not in ['Well_ID', 'Timestamp', 'Monitoring_Alert', 
                                                        'Operational_Notes', 'Well_Operating_Status',
                                                       'Maintenance_Code', 'Lubrication_Status']]
sensor_data = df[sensor_cols]

# Compute correlation matrix
corr_matrix = sensor_data.corr(method='spearman')

# Plot
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, cmap="coolwarm", annot=False, center=0)
plt.title("Spearman Correlation Between Sensors")
plt.show()

# %%
train.drop(['Well_ID'],axis=1, inplace=True)
numerical_cols = train.select_dtypes(include='number').columns
corr = train[numerical_cols].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Correlation Between Numerical Variables')
plt.tight_layout()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

X = df[sensor_cols]
y = df['Monitoring_Alert']

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X, y)

importances = model.feature_importances_
importance_df = pd.DataFrame({'Sensor': sensor_cols, 'Importance': importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(data=importance_df.head(20), x='Importance', y='Sensor')
plt.title("Top 20 Important Sensors")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering

# Fill missing values and scale
scaled = StandardScaler().fit_transform(df[sensor_cols].ffill())

# Compute correlation distance
corr_dist = 1 - np.corrcoef(scaled.T)  # distance = 1 - correlation

# Hierarchical clustering
clustering = AgglomerativeClustering(
    n_clusters=None,
    distance_threshold=0.1,
    metric='precomputed',
    linkage='average'
)
clusters = clustering.fit_predict(corr_dist)

# Show clustered sensors
clustered_df = pd.DataFrame({'Sensor': sensor_cols, 'Cluster': clusters}).sort_values('Cluster')
print(clustered_df)
# Out:
#                          Sensor  Cluster
# 14                VFD_Speed_pct        0
# 13          Tubing_Pressure_psi        1
# 11           Stroke_Count_Today        2
# 9   Polished_Rod_Vibration_mm_s        3
# 12        Surface_Temperature_C        4
# 8                Motor_Power_kW        5
# 6        Hydraulic_Pressure_psi        6
# 0        Acoustic_Sensor_Env_dB        7
# 5        Gearbox_Vibration_mm_s        8
# 10       Seismic_Activity_Index        9
# 4         Gearbox_Temperature_C       10
# 7          Liquid_Flow_Rate_m3d       11
# 3           Casing_Pressure_psi       12
# 1         Ambient_Temperature_C       13
# 2   Casing_Pressure_SensorB_psi       14

# %%
If categorical fields ~ numerical fields there are relationships, ? Xi = f(Xj)
Another cost saving idea

# %%
train = df.copy()
train['Month'] = pd.to_datetime(train['Timestamp']).dt.to_period('M').astype(str)
sns.boxplot(data=train, x='Month', y='Ambient_Temperature_C', hue='Lubrication_Status')  # example
plt.title('Ambient Temp by Month and Lubrication Status')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Idea 2: Early Warning System
# Probability of red flag: bivariate result utilization with logistic regression
# Algorithm (rules/models) for not too late intervention
#
# ## Idea 3: Operating Regime Profiling (template)
# - Cluster sensor patterns when the system is normal
# - Compare clusters between alert vs. normal conditions
# - Propose operating guidelines or thresholds to avoid alerts
